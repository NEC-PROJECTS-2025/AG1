# %% [markdown]
# ## 1.Connect to Google drive

# %%
# prompt: Connect to google drive

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### 2.Loading the dataset

# %%
# prompt: load the PulmoNets folder

from google.colab import drive

drive.mount('/content/drive/')

# %cd /content/drive/MyDrive
# %cp -a PulmoNets .
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/MyDrive
# cp: 'PulmoNets' and './PulmoNets' are the same file

# %% [markdown]
# 3.List the Contents of PulmoNet

# %%
# prompt: display the contents of PulmoNets

# !ls PulmoNets
# Out:
# Covid  Normal  Pneumonia-Bacterial  ViralPneumonia

# %% [markdown]
# 4.Displaying some random images

# %%
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Get the list of subdirectories in the PulmoNets folder.
subdirectories = [subdir for subdir in os.listdir("/content/drive/MyDrive/PulmoNets") if os.path.isdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdir))] # Filter out non-directory items

# Iterate over the subdirectories and display one image from each.
for subdirectory in subdirectories:
    # Get the list of files in the subdirectory.
    files = os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory))

    # Find the first image file in the subdirectory.
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            # Load the image.
            image_path = os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory, file)
            img = mpimg.imread(image_path)

            # Display the image.
            plt.imshow(img)
            plt.title(subdirectory)
            plt.show()
            break

# %% [markdown]
# 5.the sizes of x-ray images
# are reduced by rescaling to obtain a faster model training process. Te rescaled images are then converted to
# greyscale.

# %%
# prompt: reduce  the size of all x-ray images by rescaling of the shape Input shape (64, 64, 1)

import cv2
import os

# Get the list of subdirectories in the PulmoNets folder.
subdirectories = os.listdir("/content/drive/MyDrive/PulmoNets")

# Iterate over the subdirectories and resize the images.
for subdirectory in subdirectories:
    # Get the list of files in the subdirectory.
    files = os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory))

    # Find the first image file in the subdirectory.
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            # Load the image.
            image_path = os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory, file)
            img = cv2.imread(image_path)

            # Resize the image.
            img = cv2.resize(img, (64, 64))

            # Convert the image to grayscale.
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

            # Save the image.
            cv2.imwrite(image_path, img)

# %% [markdown]
# 6.Displaying some random images after rescaling and converting into grayscale.

# %%
# prompt: Show some images of the all subfolders after resizing

import matplotlib.pyplot as plt
import matplotlib.image as mpimg # Import the missing module
# Get the list of subdirectories in the PulmoNets folder.
subdirectories = os.listdir("/content/drive/MyDrive/PulmoNets")

# Iterate over the subdirectories and display one image from each.
for subdirectory in subdirectories:
    # Get the list of files in the subdirectory.
    files = os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory))

    # Find the first image file in the subdirectory.
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            # Load the image.
            image_path = os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory, file)
            img = mpimg.imread(image_path)

            # Display the image.
            plt.imshow(img, cmap="gray")
            plt.title(subdirectory)
            plt.show()
            break

# %% [markdown]
# 7. Displaying the size of rescaled images.

# %%
# prompt: Display the size of above rescaled images

# Get the list of subdirectories in the PulmoNets folder.
subdirectories = os.listdir("/content/drive/MyDrive/PulmoNets")

# Iterate over the subdirectories and display the size of the images.
for subdirectory in subdirectories:
    # Get the list of files in the subdirectory.
    files = os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory))

    # Find the first image file in the subdirectory.
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            # Load the image.
            image_path = os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory, file)
            img = cv2.imread(image_path)

            # Display the size of the image.
            print(f"Image size: {img.shape}")
            break
# Out:
# Image size: (64, 64, 3)
# Image size: (64, 64, 3)
# Image size: (64, 64, 3)
# Image size: (64, 64, 3)

# %% [markdown]
# 8. Image sizes are converted into grayscale

# %%
import os
import cv2

# Get the list of subdirectories in the PulmoNets folder.
subdirectories = os.listdir("/content/drive/MyDrive/PulmoNets")

# Iterate over the subdirectories and display the size of the images.
for subdirectory in subdirectories:
    # Get the list of files in the subdirectory.
    files = os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory))

    # Find the first image file in the subdirectory.
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            # Load the image.
            image_path = os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory, file)
            img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale mode

            # Reshape the image to (64, 64, 1)
            img = img.reshape((64, 64, 1))

            # Display the size of the image.
            print(f"Image size: {img.shape}")
            break
# Out:
# Image size: (64, 64, 1)
# Image size: (64, 64, 1)
# Image size: (64, 64, 1)
# Image size: (64, 64, 1)

# %% [markdown]
# 9. All the images are converted into numpy array

# %%
# prompt: convert all the resized xray images into numpy array

import numpy as np
import os
import cv2

# Get the list of subdirectories in the PulmoNets folder.
subdirectories = os.listdir("/content/drive/MyDrive/PulmoNets")

# Create an empty list to store the images.
images = []

# Iterate over the subdirectories and convert the images to numpy arrays.
for subdirectory in subdirectories:
    # Get the list of files in the subdirectory.
    files = os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory))

    # Find the first image file in the subdirectory.
    for file in files:
        if file.endswith(".jpg") or file.endswith(".png"):
            # Load the image.
            image_path = os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory, file)
            img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale mode

            # Reshape the image to (64, 64, 1)
            img = img.reshape((64, 64, 1))

            # Append the image to the list.
            images.append(img)

# Convert the list of images to a numpy array.
images = np.array(images)

# Print the shape of the numpy array.
print(images.shape)
# Out:
# (24223, 64, 64, 1)

# %% [markdown]
# 10. Normalizing the numpy array

# %%
# prompt: Normalize the above numpy array

images = images.astype('float32') / 255.0

# %% [markdown]
# 11. Splitting of the dataset into 85 % training and 15% testing

# %%
# prompt: the numpy array dataset is split into 85% training and 15% testing
# samples

from sklearn.model_selection import train_test_split

# Replace 'actual/path/to/your/labels.npy' with the actual path to your labels file
#labels = np.load('actual/path/to/your/labels.npy')

# OR

# If you need to create labels based on the image filenames or other criteria,
# write the logic here to generate the 'labels' array.
# For example, if your filenames contain the label information:
labels = []
for subdirectory in subdirectories:
    for file in os.listdir(os.path.join("/content/drive/MyDrive/PulmoNets", subdirectory)):
        if file.endswith(".jpg") or file.endswith(".png"):
            # Extract label from filename - adjust this logic based on your filename structure
            label = 1 if 'Covid' in file else 0
            labels.append(label)
labels = np.array(labels)

X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.15, random_state=42)

# %% [markdown]
# 11. Performing Data augmentation on the training data

# %%
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator

# Assuming you have X (images) and y (labels) as your original dataset


# Create an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

# Fit the ImageDataGenerator on the training data
datagen.fit(X_train)

# Generate augmented data for training
augmented_data = datagen.flow(X_train, y_train, batch_size=16)

# Train your model using the augmented data
#model.fit(augmented_data, epochs=50, validation_data=(X_test, y_test))

# %% [markdown]
# 12. Displaying the augumented data

# %%
augmented_data

# %% [markdown]
# 13. Model Design and Compiling

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Dropout, Flatten, Dense, Add, MaxPooling2D, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import Accuracy
from sklearn.model_selection import KFold # Import KFold for splitting data

def wide_residual_block(input_tensor, n_filters, dropout_rate, strides=1):
    x = Conv2D(n_filters, 3, strides=strides, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Conv2D(n_filters, 3, padding='same')(x)
    x = BatchNormalization()(x)

    if strides != 1 or input_tensor.shape[-1] != n_filters:
        input_tensor = Conv2D(n_filters, 1, strides=strides, padding='same')(input_tensor)

    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

def wide_residual_network(input_shape, depth=26, k=2, dropout_rate=0.0):
    # 5 Initial layers
    inputs = Input(shape=input_shape)
    x = Conv2D(16, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    # 2 stages, 1 block per stage (18 layers)
    for i in range(2):
        x = wide_residual_block(x, 16 * k, dropout_rate)
        if i != 1:  # No stride for last block
            x = wide_residual_block(x, 16 * k, dropout_rate, strides=2)

    # Final layers to match 26 layers
    x = AveragePooling2D((2, 2))(x)  # Average pooling layer
    x = Flatten()(x)                 # Flatten layer
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define hyperparameters and compile the model
input_shape = (64, 64, 1)
num_classes = 4  # Adjust according to your specific number of classes
model = wide_residual_network(input_shape=input_shape, depth=26, k=2, dropout_rate=0.0)
model.compile(optimizer=Adam(learning_rate=0.001), loss=categorical_crossentropy, metrics=['Accuracy()'])
# Out:
# Exception ignored in: <function _xla_gc_callback at 0x796248136a70>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/jax/_src/lib/__init__.py", line 96, in _xla_gc_callback
#     def _xla_gc_callback(*args):
# KeyboardInterrupt:

# %% [markdown]
# 14. Training the model

# %%
# prompt: Using the above model and augumented data train the model with n-fold cross-validation

from sklearn.model_selection import KFold
from tensorflow.keras.utils import to_categorical # Import to_categorical for one-hot encoding

# Define the KFold object with desired number of splits
num_splits = 3
kfold = KFold(n_splits=num_splits, shuffle=True, random_state=42)

# Initialize lists to store training and validation losses and accuracies
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Iterate through each fold
for train_index, val_index in kfold.split(X_train):
    # Split data into training and validation sets for this fold
    X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
    y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

    # One-hot encode the labels
    y_train_fold = to_categorical(y_train_fold, num_classes=num_classes) # Convert labels to one-hot encoding
    y_val_fold = to_categorical(y_val_fold, num_classes=num_classes)     # Convert labels to one-hot encoding

    # Recreate the model for each fold to reset weights
    model = wide_residual_network(input_shape=input_shape, depth=26, k=2, dropout_rate=0.0)
    model.compile(optimizer=Adam(learning_rate=0.001), loss=categorical_crossentropy, metrics=[Accuracy()])  # Remove parentheses after 'Accuracy'
    # Fit the ImageDataGenerator on the training data for this fold
    datagen.fit(X_train_fold) # Fit the generator on the current fold's training data

    # Generate augmented data for training this fold
    augmented_data = datagen.flow(X_train_fold, y_train_fold, batch_size=16) # Create the augmented data flow for the current fold

    # Train the model on the current fold's training data
    model.fit(augmented_data, steps_per_epoch=len(X_train_fold) // 16, epochs=50, validation_data=(X_val_fold, y_val_fold))

    # Evaluate the model on the current fold's validation data
    train_loss, train_accuracy = model.evaluate(X_train_fold, y_train_fold)
    val_loss, val_accuracy = model.evaluate(X_val_fold, y_val_fold)

    # Store the losses and accuracies
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)

# Print the average training and validation losses and accuracies
print("Average training loss:", sum(train_losses) / num_splits)
print("Average validation loss:", sum(val_losses) / num_splits)
print("Average training accuracy:", sum(train_accuracies) / num_splits)
print("Average validation accuracy:", sum(val_accuracies) / num_splits)
# Out:
# Epoch 1/50
# 857/857 [==============================] - 124s 141ms/step - loss: 0.0231 - accuracy: 0.1479 - val_loss: 0.0265 - val_accuracy: 0.0577
# Epoch 2/50
# 857/857 [==============================] - 121s 141ms/step - loss: 0.0063 - accuracy: 0.3021 - val_loss: 0.0031 - val_accuracy: 0.1534
# Epoch 3/50
# 857/857 [==============================] - 118s 138ms/step - loss: 0.0217 - accuracy: 0.2360 - val_loss: 8.4049e-04 - val_accuracy: 0.0834
# Epoch 4/50
# 857/857 [==============================] - 117s 137ms/step - loss: 0.0053 - accuracy: 0.2294 - val_loss: 5.3684e-04 - val_accuracy: 0.1671
# Epoch 5/50
# 857/857 [==============================] - 118s 138ms/step - loss: 9.6164e-04 - accuracy: 0.2134 - val_loss: 0.0650 - val_accuracy: 8.3783e-04
# Epoch 6/50
# 857/857 [==============================] - 118s 137ms/step - loss: 0.0044 - accuracy: 0.2600 - val_loss: 5.0896e-06 - val_accuracy: 0.3454
# Epoch 7/50
# ...

# %% [markdown]
# 14. Evaluating the model

# %%
# Import necessary library
from tensorflow.keras.utils import to_categorical


# One-hot encode y_test
y_test_encoded = to_categorical(y_test, num_classes=num_classes)

# Evaluate the model on the test data using the encoded labels
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded)

# Print the results
print("Test loss:", test_loss)
print("Test accuracy:", test_accuracy)
# Out:
# 114/114 [==============================] - 6s 56ms/step - loss: 4.9656e-04 - accuracy: 0.6675
# Test loss: 0.0004965636180713773
# Test accuracy: 0.6675151586532593

# %% [markdown]
# 15. save the above model

# %%
# prompt: save the above model

import pickle

# Save the model to a file
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
from sklearn.model_selection import train_test_split

# Assuming 'X_train' and 'y_train' are your training data and labels

# Randomly split the training dataset into three equal parts
X_train_part1, X_validation, y_train_part1, y_validation = train_test_split(X_train, y_train, test_size=1/3, random_state=42)

# Further split the remaining data into two parts for training
X_train_part2, X_train_part3, y_train_part2, y_train_part3 = train_test_split(X_train_part1, y_train_part1, test_size=0.5, random_state=42)

# Print the shapes of the datasets to verify the split
print("Training Set 1 shape:", X_train_part2.shape, y_train_part2.shape)
print("Training Set 2 shape:", X_train_part3.shape, y_train_part3.shape)
print("Validation Set shape:", X_validation.shape, y_validation.shape)
# Out:
# Training Set 1 shape: (6863, 64, 64, 1) (6863,)
# Training Set 2 shape: (6863, 64, 64, 1) (6863,)
# Validation Set shape: (6863, 64, 64, 1) (6863,)

# %%
# prompt: evaluate  precision, recall,
# and F1 score on validation set

import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score

# Predict the classes on the validation set
y_pred = model.predict(X_validation)

# Convert predicted probabilities to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate precision, recall, and F1 score
precision = precision_score(y_validation, y_pred_classes, average='micro')
recall = recall_score(y_validation, y_pred_classes, average='micro')
f1 = f1_score(y_validation, y_pred_classes, average='micro')

# Print the results
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# 215/215 [==============================] - 11s 52ms/step
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0

# %%
# Optionally, evaluate other metrics like precision, recall, F1-score, and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix

y_pred = model.predict(X_test)
y_pred_classes = y_pred.argmax(axis=-1)
# y_true should be the true labels for the test set, not a single integer
y_true = y_test # Use the original y_test array

print(classification_report(y_true, y_pred_classes))
print(confusion_matrix(y_true, y_pred_classes))
# Out:
# 114/114 [==============================] - 7s 59ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3448
#            1       0.99      1.00      1.00       186
#
#     accuracy                           1.00      3634
#    macro avg       1.00      1.00      1.00      3634
# weighted avg       1.00      1.00      1.00      3634
#
# [[3447    1]
#  [   0  186]]

# %%
# # prompt: By using above preprocessed data generate a model by using 26-layer CNN-based model motivated by a
# # wide residual network (WRN) architecture and training was done using an NVIDIA K80
# # graphics processing unit (GPU) with and batch size of
# # 16, an epoch of 50, a learning rate of 0.001, and Adam
# # optimizer were set as training parameters. Batch normalization was employed to stabilize the technique b

# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, Dense, AveragePooling2D

# # Define the WRN-26-2 model
# def wide_residual_network(input_shape, depth=26, k=2, dropout_rate=0.0):
#     n = (depth - 4) // 6

#     model = Sequential()
#     model.add(Conv2D(16, 3, padding='same', input_shape=input_shape))
#     model.add(BatchNormalization())
#     model.add(Activation('relu'))
#     model.add(Dropout(dropout_rate))

#     for i in range(n):
#         model.add(wide_residual_block(16 * k, dropout_rate))
#         model.add(wide_residual_block(16 * k, dropout_rate, strides=2))

#     model.add(AveragePooling2D((8, 8)))
#     model.add(Flatten())
#     model.add(Dense(1, activation='sigmoid'))

#     return model

# def wide_residual_block(n_filters, dropout_rate, strides=1):
#     def block(input_tensor):
#         x = Conv2D(n_filters, 3, strides=strides, padding='same')(input_tensor)
#         x = BatchNormalization()(x)
#         x = Activation('relu')(x)
#         x = Dropout(dropout_rate)(x)

#         x = Conv2D(n_filters, 3, padding='same')(x)
#         x = BatchNormalization()(x)
#         x = Activation('relu')(x)
#         x = Dropout(dropout_rate)(x)

#         if strides != 1:
#             input_tensor = Conv2D(n_filters, 1, strides=strides, padding='same')(input_tensor)

#         x = layers.add([x, input_tensor])
#         x = Activation('relu')(x)

#         return x

#     return block

# # Instantiate the model
# model = wide_residual_network(input_shape=(64, 64, 1), depth=26, k=2, dropout_rate=0.0)

# # Compile the model
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# # Train the model
# model.fit(augmented_data, epochs=50, validation_data=(X_test, y_test))

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from keras.optimizers import Adam
from keras.losses import categorical_crossentropy
from keras.metrics import Accuracy

# Define the CNN model architecture
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, img_channels)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=Adam(), loss=categorical_crossentropy, metrics=[Accuracy()])

# Train the model
model.fit(X_train, y_train, epochs=10, batch_size=16, validation_data=(X_test, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# Define the model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(4, activation='softmax')  # Assuming 4 classes for classification
])

# Assuming 'y_train' and 'y_test' are not one-hot encoded, convert them:
y_train_encoded = to_categorical(y_train, num_classes=4)  # Adjust num_classes if needed
y_test_encoded = to_categorical(y_test, num_classes=4)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=CategoricalCrossentropy(),
              metrics=['accuracy'])

# Train the model using one-hot encoded labels
history = model.fit(X_train, y_train_encoded, epochs=50, batch_size=32, validation_data=(X_test, y_test_encoded))
# Fine-tune the model iteratively
# Out:
# Epoch 1/50
# 644/644 [==============================] - 30s 45ms/step - loss: 0.0214 - accuracy: 0.9945 - val_loss: 0.0041 - val_accuracy: 0.9989
# Epoch 2/50
# 644/644 [==============================] - 28s 43ms/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.0048 - val_accuracy: 0.9992
# Epoch 3/50
# 644/644 [==============================] - 28s 43ms/step - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.0016 - val_accuracy: 0.9992
# Epoch 4/50
# 644/644 [==============================] - 28s 43ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.0028 - val_accuracy: 0.9992
# Epoch 5/50
# 644/644 [==============================] - 28s 43ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 3.4308e-04 - val_accuracy: 0.9997
# Epoch 6/50
# 644/644 [==============================] - 28s 44ms/step - loss: 8.3798e-04 - accuracy: 0.9998 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 7/50
# ...

# %%
loss, accuracy = model.evaluate(X_test, y_test_encoded)

# Print the results
print("Test loss:", loss)
print("Test accuracy:", accuracy)
# Out:
# 114/114 [==============================] - 2s 14ms/step - loss: 0.0011 - accuracy: 0.9997
# Test loss: 0.001069747842848301
# Test accuracy: 0.999724805355072

# %%
# prompt: save the above model

model.save("/content/drive/MyDrive/my_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# prompt: draw graph for test  loss, accuracy

import matplotlib.pyplot as plt

# Get the test loss and accuracy values from the history object
test_loss = history.history['loss']
test_accuracy = history.history['accuracy']

# Get the number of epochs
epochs = range(1, len(test_loss) + 1)

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot the test loss on the first subplot
ax1.plot(epochs, test_loss, label='Test Loss')
ax1.set_title('Test Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.legend()

# Plot the test accuracy on the second subplot
ax2.plot(epochs, test_accuracy, label='Test Accuracy')
ax2.set_title('Test Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.legend()

# Show the plot
plt.show()

# %%
# prompt: Evaluate the above model using f1 square,recall,precision

import numpy as np
from sklearn.metrics import f1_score, recall_score, precision_score

y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test_encoded, axis=1)

f1_score_square = f1_score(y_true, y_pred_classes, average='macro')
recall_score_square = recall_score(y_true, y_pred_classes, average='macro')
precision_score_square = precision_score(y_true, y_pred_classes, average='macro')

print("F1 Score (Macro):", f1_score_square)
print("Recall Score (Macro):", recall_score_square)
print("Precision Score (Macro):", precision_score_square)
# Out:
# 114/114 [==============================] - 2s 13ms/step
# F1 Score (Macro): 0.9985797958173149
# Recall Score (Macro): 0.9973118279569892
# Precision Score (Macro): 0.9998550304436069

# %%
# prompt: draw the graph for the test loss and loss

import matplotlib.pyplot as plt
# Create a figure with two subplots
plt.figure(figsize=(12, 4))

# First subplot: Training and validation loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Second subplot: Training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Display the figure
plt.show()

# %%
# prompt: draw the graph for the test acc and loss , generate confusion matrix

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# Plot the training and testing accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# Generate the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
# prompt: Model Accuracy per epoch for 4 class classifcation draw the graph test acc and loss

import matplotlib.pyplot as plt

# Extract the training and validation accuracy values from the history object
train_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Extract the training and validation loss values from the history object
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Get the number of epochs
epochs = range(len(train_accuracy))

# Create a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot the training and validation accuracy on the first subplot
ax1.plot(epochs, train_accuracy, label='Training Accuracy')
ax1.plot(epochs, val_accuracy, label='Validation Accuracy')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Plot the training and validation loss on the second subplot
ax2.plot(epochs, train_loss, label='Training Loss')
ax2.plot(epochs, val_loss, label='Validation Loss')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Loss')
ax2.legend()

# Show the plot
plt.show()

# %%
# prompt: Evaluate the above model

import matplotlib.pyplot as plt


# Plot the training and validation accuracy over epochs
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.utils import to_categorical

# Assuming X_train and y_train are already defined
# Assuming y_train and y_test contain labels for 3 classes: Bacterial Pneumonia, Covid-19, and Healthy

# Define the model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # 3 classes for classification
])

# Convert labels to one-hot encoding
y_train_encoded = to_categorical(y_train, num_classes=3)
y_test_encoded = to_categorical(y_test, num_classes=3)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=CategoricalCrossentropy(),
              metrics=['accuracy'])

# Train the model using one-hot encoded labels
history = model.fit(X_train, y_train_encoded, epochs=50, batch_size=32, validation_data=(X_test, y_test_encoded))

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded)

print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')

# Calculate additional metrics
from sklearn.metrics import precision_score, recall_score, f1_score

# Predict the classes for the test set
y_test_pred = model.predict(X_test)
y_test_pred_classes = y_test_pred.argmax(axis=1)

# Use the one-hot encoded y_test for calculating metrics
y_test_true_classes = y_test_encoded.argmax(axis=1)  # Get true classes from one-hot encoded labels

precision = precision_score(y_test_true_classes, y_test_pred_classes, average='weighted')
recall = recall_score(y_test_true_classes, y_test_pred_classes, average='weighted')
f1 = f1_score(y_test_true_classes, y_test_pred_classes, average='weighted')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Epoch 1/50
# 644/644 [==============================] - 30s 45ms/step - loss: 0.0186 - accuracy: 0.9948 - val_loss: 0.0059 - val_accuracy: 0.9989
# Epoch 2/50
# 644/644 [==============================] - 28s 44ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0037 - val_accuracy: 0.9992
# Epoch 3/50
# 644/644 [==============================] - 29s 45ms/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.0013 - val_accuracy: 0.9992
# Epoch 4/50
# 644/644 [==============================] - 29s 45ms/step - loss: 4.3305e-04 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 0.9994
# Epoch 5/50
# 644/644 [==============================] - 29s 45ms/step - loss: 5.1077e-04 - accuracy: 0.9999 - val_loss: 0.0013 - val_accuracy: 0.9994
# Epoch 6/50
# 644/644 [==============================] - 28s 44ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.0026 - val_accuracy: 0.9992
# Epoch 7/50
# ...

# %%
# prompt: Display the confusion matrix for above

from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming y_test_true_classes and y_test_pred_classes are already defined

# Generate the confusion matrix
cm = confusion_matrix(y_test_true_classes, y_test_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.utils import to_categorical

# Assuming X_train and y_train are already defined
# Assuming y_train and y_test contain labels for 3 classes: Bacterial Pneumonia, Covid-19, and Healthy

# Define the model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(64, 64, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')  # 3 classes for classification, make sure this matches the one-hot encoding
])

# Convert labels to one-hot encoding
y_train_encoded = to_categorical(y_train, num_classes=3) # Ensure num_classes is consistent
y_test_encoded = to_categorical(y_test, num_classes=3) # Ensure num_classes is consistent

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.001),
              loss=CategoricalCrossentropy(),
              metrics=['accuracy'])

# Train the model using one-hot encoded labels
history = model.fit(X_train, y_train_encoded, epochs=50, batch_size=32, validation_data=(X_test, y_test_encoded))

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(X_test, y_test_encoded)

print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')

# Calculate additional metrics
from sklearn.metrics import precision_score, recall_score, f1_score

# Predict the classes for the test set
y_test_pred = model.predict(X_test)
y_test_pred_classes = y_test_pred.argmax(axis=1)

# Use the one-hot encoded y_test for calculating metrics
y_test_true_classes = y_test_encoded.argmax(axis=1)  # Get true classes from one-hot encoded labels

precision = precision_score(y_test_true_classes, y_test_pred_classes, average='weighted')
recall = recall_score(y_test_true_classes, y_test_pred_classes, average='weighted')
f1 = f1_score(y_test_true_classes, y_test_pred_classes, average='weighted')

print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')
# Out:
# Epoch 1/50
# 644/644 [==============================] - 29s 44ms/step - loss: 0.0200 - accuracy: 0.9940 - val_loss: 0.0061 - val_accuracy: 0.9986
# Epoch 2/50
# 644/644 [==============================] - 27s 42ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0019 - val_accuracy: 0.9992
# Epoch 3/50
# 644/644 [==============================] - 28s 43ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0015 - val_accuracy: 0.9997
# Epoch 4/50
# 644/644 [==============================] - 27s 42ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 7.7887e-04 - val_accuracy: 0.9994
# Epoch 5/50
# 644/644 [==============================] - 27s 42ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 9.5596e-04 - val_accuracy: 0.9994
# Epoch 6/50
# 644/644 [==============================] - 27s 43ms/step - loss: 5.7979e-05 - accuracy: 1.0000 - val_loss: 4.8791e-05 - val_accuracy: 1.0000
# Epoch 7/50
# ...

# %%
# prompt: confusion matrix of above

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Assuming y_test_true_classes and y_test_pred_classes are already defined

# Generate the confusion matrix
cm = confusion_matrix(y_test_true_classes, y_test_pred_classes)

# Plot the confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Dropout, Flatten, Dense, Add, MaxPooling2D, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import Accuracy
from sklearn.model_selection import KFold # Import KFold for splitting data

def wide_residual_block(input_tensor, n_filters, dropout_rate, strides=1):
    x = Conv2D(n_filters, 3, strides=strides, padding='same')(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    x = Conv2D(n_filters, 3, padding='same')(x)
    x = BatchNormalization()(x)

    if strides != 1 or input_tensor.shape[-1] != n_filters:
        input_tensor = Conv2D(n_filters, 1, strides=strides, padding='same')(input_tensor)

    x = Add()([x, input_tensor])
    x = Activation('relu')(x)
    return x

def wide_residual_network(input_shape, depth=26, k=2, dropout_rate=0.0):
    # 5 Initial layers
    inputs = Input(shape=input_shape)
    x = Conv2D(16, 3, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(dropout_rate)(x)

    # 2 stages, 1 block per stage (18 layers)
    for i in range(2):
        x = wide_residual_block(x, 16 * k, dropout_rate)
        if i != 1:  # No stride for last block
            x = wide_residual_block(x, 16 * k, dropout_rate, strides=2)

    # Final layers to match 26 layers
    x = AveragePooling2D((2, 2))(x)  # Average pooling layer
    x = Flatten()(x)                 # Flatten layer
    outputs = Dense(num_classes, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# Define hyperparameters and compile the model
input_shape = (64, 64, 1)
num_classes = 4  # Adjust according to your specific number of classes
model = wide_residual_network(input_shape=input_shape, depth=26, k=2, dropout_rate=0.0)
model.compile(optimizer=Adam(learning_rate=0.001), loss=categorical_crossentropy, metrics=['Accuracy()'])

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import os

# Specify the directory containing the image files
pulmonets_dir = '/content/drive/MyDrive/PulmoNets'

# List all subdirectories (categories) in the directory
category_list = [d for d in os.listdir(pulmonets_dir) if os.path.isdir(os.path.join(pulmonets_dir, d))]

# Randomly select a category
random_category_index = np.random.randint(0, len(category_list))
selected_category = category_list[random_category_index]

# Get the path to the selected category directory
category_dir = os.path.join(pulmonets_dir, selected_category)

# List all image files within the selected category directory
image_list = [f for f in os.listdir(category_dir) if os.path.isfile(os.path.join(category_dir, f))]

# Randomly select an image file
random_image_index = np.random.randint(0, len(image_list))
selected_image = image_list[random_image_index]

# Get the full path to the selected image file
selected_file = os.path.join(category_dir, selected_image)

# Load the image using PIL
image = Image.open(selected_file).convert('L') # Assuming grayscale images

# Convert the image to a NumPy array
image_array = np.array(image)
# Preprocess the image
image_array = image_array.astype('float32')

# %%
# prompt: By using above model randomly select an image from PulmoNets and evaluate it

import matplotlib.pyplot as plt
import numpy as np
image_array /= 255.0
image_array = np.expand_dims(image_array, axis=0)
image_array = np.expand_dims(image_array, axis=3)

# Predict the class of the image
predictions = model.predict(image_array)
predicted_class = np.argmax(predictions)

# Get the name of the predicted class
class_names = ['Bacterial Pneumonia', 'COVID-19', 'Healthy', 'Viral Pneumonia']
predicted_class_name = class_names[predicted_class]

# Print the results
print("Selected Image:")
plt.imshow(image_array[0, :, :, 0], cmap='gray')
plt.axis('off')
plt.show()
print("Predicted Class:", predicted_class_name)
# Out:
# 1/1 [==============================] - 0s 345ms/step
# Selected Image:
# Predicted Class: Healthy
